# %%
import pandas as pd
data = pd.DataFrame(data={'Location': ['a', 'b', 'c', 'd', 'e'], 'Location Code': [2, 3, 6, 10, 15]})

# %%
data
# Out:
#   Location  Location Code
# 0        a              2
# 1        b              3
# 2        c              6
# 3        d             10
# 4        e             15

# %%
code = data["Location Code"]
print(type)
